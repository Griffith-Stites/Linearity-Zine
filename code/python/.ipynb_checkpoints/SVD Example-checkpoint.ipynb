# %% [markdown]
# # SVD Example in Python

# %% [markdown]
# ## Python SVD Basics

# %%
import numpy as np
from numpy import ndarray

# %% [markdown]
# View the documentation on the numpy linear algebra [here](https://docs.scipy.org/doc/numpy-1.16.1/reference/routines.linalg.html).

# %% [markdown]
# First lets define a matrix:

# %%
A = np.matrix('1 2 3; 4 5 6')
print (A)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %% [markdown]
# Next lets perform the SVD on that matrix:

# %%
U, S, V = np.linalg.svd(A, full_matrices = True)
print('U = \n', U, '\n\nS = \n', S, '\n\nV = \n', V)
# Out:
# U =
#  [[-0.3863177  -0.92236578]
#  [-0.92236578  0.3863177 ]]
#
# S =
#  [9.508032   0.77286964]
#
# V =
#  [[-0.42866713 -0.56630692 -0.7039467 ]
#  [ 0.80596391  0.11238241 -0.58119908]
#  [ 0.40824829 -0.81649658  0.40824829]]

# %% [markdown]
# Let's do the same thing but make S a diagonal matrix.
# This is because numpy just gives the singular values without placing the zeros.

# %%
U, S, V = np.linalg.svd(A, full_matrices = True)
S = np.diag(S)
print('U = \n', U, '\n\nS = \n', S, '\n\nV = \n', V)
# Out:
# U =
#  [[-0.3863177  -0.92236578]
#  [-0.92236578  0.3863177 ]]
#
# S =
#  [[9.508032   0.        ]
#  [0.         0.77286964]]
#
# V =
#  [[-0.42866713 -0.56630692 -0.7039467 ]
#  [ 0.80596391  0.11238241 -0.58119908]
#  [ 0.40824829 -0.81649658  0.40824829]]

# %% [markdown]
# Oops, S is not the right size still, we need S to have one more column of zeros:

# %%
S_dim = S.shape # create a tuple of the dimensions
S_new = np.zeros((S_dim[0], S_dim[1]+1)) # matrix of zeros one more column than S
print(S_new)

S_new[:,:-1] = S
print('\nU = \n', U, '\n\nS_new = \n', S_new, '\n\nV = \n', V)
# Out:
# [[0. 0. 0.]
#  [0. 0. 0.]]
#
# U =
#  [[-0.3863177  -0.92236578]
#  [-0.92236578  0.3863177 ]]
#
# S_new =
#  [[9.508032   0.         0.        ]
#  [0.         0.77286964 0.        ]]
#
# V =
#  [[-0.42866713 -0.56630692 -0.7039467 ]
#  [ 0.80596391  0.11238241 -0.58119908]
#  [ 0.40824829 -0.81649658  0.40824829]]

# %% [markdown]
# Much better.
#
# Now, lets varify that we can reconstruct A with these three matricies.

# %%
U @ S_new @ V
# Out:
# matrix([[1., 2., 3.],
#         [4., 5., 6.]])

# %% [markdown]
# As a quick note, we do not need to find the complex conjugate transponse like we did in matlab. When using the SVD tool in numpy, V is returned that way by default.
#
# Sweet! Now time for SVD on an image.

# %% [markdown]
# ## Python SVD on Image

# %% [markdown]
# First lets load in the cat image:

# %%
import imageio
import matplotlib.pyplot as plt # matlab like plotting functions

img = Image.open('cat.jpg')
plt.imshow(img, cmap=plt.cm.gray)
plt.show()

# %% [markdown]
# Next, lets convert the image to a matrix:

# %%
img_m = np.fromfile('cat.jpg')
print(type(img_m),'\n\n', img_m)
# Out:
# <class 'numpy.ndarray'>
#
#  [ 4.12977010e+030  6.80731539e+038  5.93185986e+014 ...  2.55032669e-303
#  -1.64283476e-299  1.28741317e+156]

# %%
U, S, V = np.linalg.svd(img_m, full_matrices = True)
S = np.diag(S)
print('U = \n', U, '\n\nS = \n', S, '\n\nV = \n', V)
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-51-c5c8088c35ce> in <module>
# ----> 1 U, S, V = np.linalg.svd(img_m, full_matrices = True)
#       2 S = np.diag(S)
#       3 print('U = \n', U, '\n\nS = \n', S, '\n\nV = \n', V)
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/linalg/linalg.py in svd(a, full_matrices, compute_uv)
#    1541     a, wrap = _makearray(a)
#    1542     _assertNoEmpty2d(a)
# -> 1543     _assertRankAtLeast2(a)
#    1544     t, result_t = _commonType(a)
#    1545
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/linalg/linalg.py in _assertRankAtLeast2(*arrays)
#     202         if a.ndim < 2:
#     203             raise LinAlgError('%d-dimensional array given. Array must be '
# --> 204                     'at least two-dimensional' % a.ndim)
#     205
#     206 def _assertSquareness(*arrays):
#
# LinAlgError: 1-dimensional array given. Array must be at least two-dimensional

# %%
face.tofile('face.raw') # Create raw file
face_from_raw = np.fromfile('face.raw', dtype=np.uint8)

face_from_raw.shape

face_from_raw.shape = (768, 1024, 3)
type(face_from_raw)
# Out:
# numpy.ndarray

# %%
# img_m = misc.imread('cat.jpg')
from scipy import misc

face = misc.face()
print(type(face))
# misc.imsave('face.png', face) # First we need to create the PNG filez
face = misc.imread('face.png')

type(face)
# Out:
# <class 'numpy.ndarray'>
# /home/griffith/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   import sys
# numpy.ndarray

# %% [markdown]
# https://scipy-lectures.org/advanced/image_processing/
